# %% [markdown]
# ## Matplotlib
# Matplotlib ject biblioteką umożliwiającą rysowanie wykresów w Pythonie. Przedstawie jej kilka możliwości. Importujemy ją w następujący sposób:

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Wykresy 2D

# %%
x = np.arange(0,11)
# wykres punktowy
plt.scatter(x, [1,2,2.5,3,2.5,2,1,2,2,4,3.5], c="red")
# wykres liniowy
plt.plot(x, [2,2.1,2.2,2.5,2.8,2.9,3,3,3,3,2.9])

x = np.linspace(0,10,100)
def f(x):
    return np.sin(x - np.pi) + 1.5
# Kilkukrotnie wywołując funkcję rysującą w jednej komórce nanosimy wszystko na jeden wykres
plt.plot(x, f(x), c="green")

plt.ylim([0,5]) # Możemy ustawić zakres osi (opcjonalnie), jest też analogiczne polecenie xlim
plt.ylabel("Wartości")
plt.xlabel("Argumenty")
plt.title("Jakiś wykres")
# Out:
# Text(0.5, 1.0, 'Jakiś wykres')

# %% [markdown]
# ### Wykresy 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = Axes3D(plt.figure())
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z ** 2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z)

# %%
ax = Axes3D(plt.figure())
def f2(x,y):
    return (y - x ** 2) * (y - 3 * x ** 2)
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
xx, yy = np.meshgrid(x,y)
ax.plot_surface(xx,yy,f2(xx,yy))

# %%
# Ta metoda "cell magic" sprawi, że wykresy będą wyświetlać się w notebooku w trybie interaktywnym.
# %matplotlib notebook

# %%
ax = Axes3D(plt.figure())
def f2(x,y):
    return (y - x ** 2) * (y - 3 * x ** 2)
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
xx, yy = np.meshgrid(x,y)
ax.plot_surface(xx,yy,f2(xx,yy))
# Out:
# <div id='6e1db9f0-a67c-4171-b150-e2c0196ce201'></div>

# %% [markdown]
# ### Zadanie
# Zwizualizuj funkcję z zadania nr 4 z zestawu nr 1 i zaznacz przy tym trójkąt, w ramach którego poszukujemy ekstremum. Efekt powinien być podobny do tego, co poniżej:

# %%
## Wpisz kod tutaj
# Out:
# <img src="data:image/png;base64,..." width="640">
